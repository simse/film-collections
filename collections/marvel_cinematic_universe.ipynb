# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import pandas as pd
import os

# %%
# %run ./utils/save_result.ipynb

# %%
# load table from wikipedia
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films", header=0)

filmography_table = pd.concat([tables[1], tables[2]])

filmography_table.drop(columns=["Screenwriter(s)", "Producer(s)", "Unnamed: 5", "Status"], axis=1, inplace=True)

# %%
# display table
filmography_table
# Out:
#                                            Film      U.S. release date  \
# 0                                 Phase One[24]          Phase One[24]
# 1                                      Iron Man            May 2, 2008
# 2                           The Incredible Hulk          June 13, 2008
# 3                                    Iron Man 2            May 7, 2010
# 4                                          Thor            May 6, 2011
# 5            Captain America: The First Avenger          July 22, 2011
# 6                                  The Avengers            May 4, 2012
# 7                                 Phase Two[24]          Phase Two[24]
# 8                                    Iron Man 3            May 3, 2013
# 9                          Thor: The Dark World       November 8, 2013
# 10          Captain America: The Winter Soldier          April 4, 2014
# 11                      Guardians of the Galaxy         August 1, 2014
# 12                      Avengers: Age of Ultron            May 1, 2015
# 13                                      Ant-Man          July 17, 2015
# 14                              Phase Three[24]        Phase Three[24]
# 15                   Captain America: Civil War            May 6, 2016
# 16                               Doctor Strange       November 4, 2016
# 17               Guardians of the Galaxy Vol. 2            May 5, 2017
# 18                       Spider-Man: Homecoming           July 7, 2017
# 19                               Thor: Ragnarok       November 3, 2017
# 20                                Black Panther      February 16, 2018
# 21                       Avengers: Infinity War         April 27, 2018
# 22                         Ant-Man and the Wasp           July 6, 2018
# 23                               Captain Marvel          March 8, 2019
# 24                            Avengers: Endgame         April 26, 2019
# 25                    Spider-Man: Far From Home           July 2, 2019
# 0                                Phase Four[69]         Phase Four[69]
# 1                                   Black Widow        July 9, 2021[b]
# 2     Shang-Chi and the Legend of the Ten Rings      September 3, 2021
# 3                                      Eternals       November 5, 2021
# 4                       Spider-Man: No Way Home      December 17, 2021
# 5   Doctor Strange in the Multiverse of Madness            May 6, 2022
# 6                        Thor: Love and Thunder           July 8, 2022
# 7                Black Panther: Wakanda Forever      November 11, 2022
# 8                                Phase Five[86]         Phase Five[86]
# 9             Ant-Man and the Wasp: Quantumania  February 17, 2023[87]
# 10               Guardians of the Galaxy Vol. 3        May 5, 2023[90]
# 11                                  The Marvels      July 28, 2023[87]
# 12             Captain America: New World Order        May 3, 2024[21]
# 13                                 Thunderbolts      July 26, 2024[21]
# 14                                        Blade  September 6, 2024[97]
# 15                            Phase Six[68][99]      Phase Six[68][99]
# 16                                   Deadpool 3   November 8, 2024[97]
# 17                               Fantastic Four  February 14, 2025[97]
# 18                   Avengers: The Kang Dynasty        May 2, 2025[21]
# 19                        Avengers: Secret Wars        May 1, 2026[97]
#
#                     Director(s)
# 0                 Phase One[24]
# 1               Jon Favreau[27]
# 2           Louis Leterrier[29]
# 3               Jon Favreau[31]
# 4           Kenneth Branagh[33]
# 5              Joe Johnston[35]
# 6               Joss Whedon[37]
# 7                 Phase Two[24]
# 8               Shane Black[38]
# 9               Alan Taylor[40]
# 10    Anthony and Joe Russo[42]
# 11               James Gunn[44]
# 12              Joss Whedon[46]
# 13              Peyton Reed[47]
# 14              Phase Three[24]
# 15    Anthony and Joe Russo[49]
# 16         Scott Derrickson[50]
# 17               James Gunn[45]
# 18                Jon Watts[52]
# 19            Taika Waititi[54]
# 20             Ryan Coogler[57]
# 21    Anthony and Joe Russo[60]
# 22              Peyton Reed[62]
# 23  Anna Boden & Ryan Fleck[64]
# 24    Anthony and Joe Russo[60]
# 25                Jon Watts[66]
# 0                Phase Four[69]
# 1            Cate Shortland[71]
# 2     Destin Daniel Cretton[73]
# 3                Chloé Zhao[75]
# 4                 Jon Watts[78]
# 5                 Sam Raimi[80]
# 6             Taika Waititi[82]
# 7              Ryan Coogler[84]
# 8                Phase Five[86]
# 9               Peyton Reed[88]
# 10               James Gunn[91]
# 11              Nia DaCosta[92]
# 12              Julius Onah[94]
# 13            Jake Schreier[94]
# 14             Yann Demange[98]
# 15            Phase Six[68][99]
# 16              Shawn Levy[100]
# 17            Matt Shakman[101]
# 18    Destin Daniel Cretton[94]
# 19                          TBA

# %%
# filter out phase rows
filmography_table.drop(filmography_table[filmography_table["Film"].str.startswith("Phase")].index, inplace=True)

# %%
# parse director column
filmography_table = filmography_table.rename(columns={"Director(s)": "Director"})

filmography_table["Director"] = filmography_table["Director"].apply(lambda x: x.split("[")[0])

filmography_table = filmography_table[filmography_table["Director"] != "TBA"]

filmography_table.iloc[0]
# Out:
# Film                    Iron Man
# U.S. release date    May 2, 2008
# Director             Jon Favreau
# Name: 1, dtype: object

# %%
# parse release date column
filmography_table = filmography_table.rename(columns={"U.S. release date": "Year"})

# remove wikipedia reference tags
filmography_table["Year"] = filmography_table["Year"].apply(lambda x: x.split("[")[0])

# extract last four numbers
filmography_table["Year"] = filmography_table["Year"].apply(lambda x: int(str(x)[-4:]))

# %%
# convert dataframe to exportable list
films = []

for film in filmography_table.values.tolist():
    films.append({
        "title": film[0],
        "year": film[1],
        "director": film[2]
    })

films[0]
# Out:
# {'title': 'Iron Man', 'year': 2008, 'director': 'Jon Favreau'}

# %%
save("Marvel Cinematic Universe", "All feature films in the Marvel Cinematic Universe (all phases)", "https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films", films) # type: ignore
# Out:
# https://film-collections.simse.dev/marvel-cinematic-universe.json
